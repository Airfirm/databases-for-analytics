# %%
## import necessary libraries

import pandas as pd
from sqlalchemy import create_engine

# %%
## Read the TSV file safely

file_path = r"C:\Users\ogsal\OneDrive\Desktop\NWMSU\exercise_07\name.basics.tsv"

df = pd.read_csv(
    file_path,
    sep="\t",
    encoding="cp1252",
    encoding_errors="ignore",  # <-- KEY FIX
    na_values="\\N",
    low_memory=False
)

# %%
## Display the first 20 rows of the DataFrame

df.head(20)
# Out:
#        nconst          primaryName  birthYear  deathYear  \
# 0   nm0000001         Fred Astaire     1899.0     1987.0
# 1   nm0000002        Lauren Bacall     1924.0     2014.0
# 2   nm0000003      Brigitte Bardot     1934.0     2025.0
# 3   nm0000004         John Belushi     1949.0     1982.0
# 4   nm0000005       Ingmar Bergman     1918.0     2007.0
# 5   nm0000006       Ingrid Bergman     1915.0     1982.0
# 6   nm0000007      Humphrey Bogart     1899.0     1957.0
# 7   nm0000008        Marlon Brando     1924.0     2004.0
# 8   nm0000009       Richard Burton     1925.0     1984.0
# 9   nm0000010         James Cagney     1899.0     1986.0
# 10  nm0000011          Gary Cooper     1901.0     1961.0
# 11  nm0000012          Bette Davis     1908.0     1989.0
# 12  nm0000013            Doris Day     1922.0     2019.0
# 13  nm0000014  Olivia de Havilland     1916.0     2020.0
# 14  nm0000015           James Dean     1931.0     1955.0
# ...

# %%
df.columns
# Out:
# Index(['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession',
#        'knownForTitles'],
#       dtype='object')

# %%
## Drop unnecessary columns if they exist

## df = df.drop(columns=["name_id"], errors="ignore")

# %%
print(df.columns.tolist())
# Out:
# ['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession', 'knownForTitles']

# %%
## Rename columns to match PostgreSQL table

df = df.rename(columns={
    "nconst": "nconst",
    "primaryName": "primary_name",
    "birthYear": "birth_year",
    "deathYear": "death_year",
    "primaryProfession": "primary_profession",
    "knownForTitles": "known_for_titles"
})

# %%
## Connect to PostgreSQL

engine = create_engine("postgresql+psycopg2://postgres:IreKayin01$$$@localhost:5432/movies_db")

# %%
## Test connection

engine.connect()

# %%
## Load data into PostgreSQL table

df.to_sql(
    "name_basics",
    engine,
    if_exists="append",
    index=False,
    chunksize=10000,
    method="multi"
)
# Out:
# 15053659
